# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
max_precipitacion_anual = pd.read_excel(io ='Estaciones.xlsx', sheet_name="Maximos",usecols=['Unnamed: 0','Unnamed: 13'])
max_precipitacion_anual.head()
# Out:
#   Unnamed: 0       Unnamed: 13
# 0    Año hid  San Luis Tucuman
# 1       1946               NaN
# 2       1947               NaN
# 3       1948               NaN
# 4       1949               NaN

# %%
tot_precipitacion_anual = pd.read_excel(io ='Estaciones.xlsx', sheet_name="Anuales",usecols=['Unnamed: 0','Unnamed: 13'])
tot_precipitacion_anual.head()
# Out:
#   Unnamed: 0       Unnamed: 13
# 0    Año hid  San Luis Tucuman
# 1       1946               NaN
# 2       1947               NaN
# 3       1948               NaN
# 4       1949               NaN

# %%
max_precipitacion_anual.rename(columns={'Unnamed: 0':'año', 'Unnamed: 13':'San Luis'},inplace=True)
max_precipitacion_anual.dropna(inplace=True)

# %%
max_precipitacion_anual
# Out:
#         año          San Luis
# 0   Año hid  San Luis Tucuman
# 28     1973               300
# 29     1974               160
# 30     1975               110
# 31     1976               145
# 32     1977                96
# 33     1978                81
# 34     1979                76
# 35     1980                76
# 36     1981               107
# 37     1982                62
# 38     1983               122
# 39     1984                96
# 40     1985                94
# 41     1986                50
# 42     1987                51
# 43     1988                90
# 44     1989               179
# 45     1990                45
# 46     1991                67
# 47     1992                67
# 48     1993                88
# 49     1994                71
# 50     1995                63
# 51     1996               122
# 52     1997                67
# 53     1998                65
# 54     1999                73
# 55     2000               102
# 56     2001                91
# 57     2002               150
# 58     2003                75
# 59     2004                96
# 60     2005                73

# %%
tot_precipitacion_anual.rename(columns={'Unnamed: 0':'año', 'Unnamed: 13':'San Luis'},inplace=True)

# %%
tot_precipitacion_anual.drop([0],axis=0,inplace=True)

# %%
tot_precipitacion_anual.dropna(inplace=True)

# %%
tot_precipitacion_anual
# Out:
#      año San Luis
# 28  1973     1287
# 29  1974     1376
# 30  1975    852.5
# 31  1976     1140
# 32  1977     1034
# 33  1978      917
# 34  1979     1260
# 35  1980     1206
# 36  1981     1182
# 37  1982      932
# 38  1983     1244
# 39  1984   1158.1
# 40  1985      975
# 41  1986     1002
# 42  1987      868
# 43  1988     1373
# 44  1989      501
# 45  1990      683
# 46  1991     1085
# 47  1992      860
# 48  1993     1027
# 49  1994      823
# 50  1995      624
# 51  1996      830
# 52  1997     1041
# 53  1998      979
# 54  1999     1058
# 55  2000     1132
# 56  2001     1334
# 57  2002      938
# 58  2003      849
# 59  2004      825
# 60  2005      818

# %%
max_precipitacion_anual.rename(columns={ 'San Luis':'max_precipitacion_anual'},inplace=True)
tot_precipitacion_anual.rename(columns={'San Luis':'tot_precipitacion_anual'},inplace=True)

# %%
precipitacion_anual_sanluis= tot_precipitacion_anual.merge(max_precipitacion_anual,on='año')
precipitacion_anual_sanluis
# Out:
#      año tot_precipitacion_anual max_precipitacion_anual
# 0   1973                    1287                     300
# 1   1974                    1376                     160
# 2   1975                   852.5                     110
# 3   1976                    1140                     145
# 4   1977                    1034                      96
# 5   1978                     917                      81
# 6   1979                    1260                      76
# 7   1980                    1206                      76
# 8   1981                    1182                     107
# 9   1982                     932                      62
# 10  1983                    1244                     122
# 11  1984                  1158.1                      96
# 12  1985                     975                      94
# 13  1986                    1002                      50
# 14  1987                     868                      51
# 15  1988                    1373                      90
# 16  1989                     501                     179
# 17  1990                     683                      45
# 18  1991                    1085                      67
# 19  1992                     860                      67
# 20  1993                    1027                      88
# 21  1994                     823                      71
# 22  1995                     624                      63
# 23  1996                     830                     122
# 24  1997                    1041                      67
# 25  1998                     979                      65
# 26  1999                    1058                      73
# 27  2000                    1132                     102
# 28  2001                    1334                      91
# 29  2002                     938                     150
# 30  2003                     849                      75
# 31  2004                     825                      96
# 32  2005                     818                      73

# %%
variables_e_indices_NDEFM = pd.read_excel("variables e indices NDEFM.xlsx")
variables_e_indices_NDEFM.head()
# Out:
#     año  humedad esp (g/kg)  omega (Pa/s)  SLP PACIFICO      P ATL   \
# 0  1949              8.7958      0.002598      1018.8150  1017.2874
# 1  1950             10.6268     -0.022770      1019.0520  1015.9596
# 2  1951             10.2252     -0.020314      1018.1772  1016.6636
# 3  1952             11.3264     -0.026402      1019.0196  1016.5650
# 4  1953             11.2208     -0.024602      1020.5140  1016.7198
#
#    indice SOI  indice SAM
# 0         NaN          NaN NaN
# 1         NaN          NaN NaN
# 2         NaN          NaN NaN
# 3       -0.50          NaN NaN
# 4       -0.32          NaN NaN

# %%
año_soi = variables_e_indices_NDEFM[['año','indice SOI']]
año_soi
# Out:
#      año  indice SOI
# 0   1949         NaN
# 1   1950         NaN
# 2   1951         NaN
# 3   1952       -0.50
# 4   1953       -0.32
# ..   ...         ...
# 56  2005       -0.80
# 57  2006        0.68
# 58  2007       -0.18
# 59  2008        1.68
# 60  2009        1.22
#
# [61 rows x 2 columns]

# %%
san_luis_soi = precipitacion_anual_sanluis.merge(año_soi)
san_luis_soi
# Out:
#      año tot_precipitacion_anual max_precipitacion_anual  indice SOI
# 0   1973                    1287                     300       -0.52
# 1   1974                    1376                     160        2.26
# 2   1975                   852.5                     110        0.40
# 3   1976                    1140                     145        1.62
# 4   1977                    1034                      96        0.14
# 5   1978                     917                      81       -1.12
# 6   1979                    1260                      76        0.12
# 7   1980                    1206                      76       -0.16
# 8   1981                    1182                     107       -0.30
# 9   1982                     932                      62        0.56
# 10  1983                    1244                     122       -2.86
# 11  1984                  1158.1                      96        0.16
# 12  1985                     975                      94        0.38
# 13  1986                    1002                      50        0.10
# 14  1987                     868                      51       -1.16
# 15  1988                    1373                      90       -0.08
# 16  1989                     501                     179        1.34
# 17  1990                     683                      45       -0.60
# 18  1991                    1085                      67       -0.10
# 19  1992                     860                      67       -1.66
# 20  1993                    1027                      88       -0.68
# 21  1994                     823                      71       -0.08
# 22  1995                     624                      63       -0.30
# 23  1996                     830                     122        0.38
# 24  1997                    1041                      67        0.52
# 25  1998                     979                      65       -1.86
# 26  1999                    1058                      73        1.30
# 27  2000                    1132                     102        1.22
# 28  2001                    1334                      91        1.24
# 29  2002                     938                     150        0.24
# 30  2003                     849                      75       -0.56
# 31  2004                     825                      96        0.22
# 32  2005                     818                      73       -0.80

# %%
san_luis_soi['ultimos_10'] = san_luis_soi['año'].between(1990, 2000)

# %%
san_luis_soi['max_precipitacion_anual'] = san_luis_soi['max_precipitacion_anual'].astype(int)
san_luis_soi
# Out:
#      año tot_precipitacion_anual  max_precipitacion_anual  indice SOI  \
# 0   1973                    1287                      300       -0.52
# 1   1974                    1376                      160        2.26
# 2   1975                   852.5                      110        0.40
# 3   1976                    1140                      145        1.62
# 4   1977                    1034                       96        0.14
# 5   1978                     917                       81       -1.12
# 6   1979                    1260                       76        0.12
# 7   1980                    1206                       76       -0.16
# 8   1981                    1182                      107       -0.30
# 9   1982                     932                       62        0.56
# 10  1983                    1244                      122       -2.86
# 11  1984                  1158.1                       96        0.16
# 12  1985                     975                       94        0.38
# 13  1986                    1002                       50        0.10
# 14  1987                     868                       51       -1.16
# 15  1988                    1373                       90       -0.08
# 16  1989                     501                      179        1.34
# 17  1990                     683                       45       -0.60
# 18  1991                    1085                       67       -0.10
# 19  1992                     860                       67       -1.66
# 20  1993                    1027                       88       -0.68
# 21  1994                     823                       71       -0.08
# 22  1995                     624                       63       -0.30
# 23  1996                     830                      122        0.38
# 24  1997                    1041                       67        0.52
# 25  1998                     979                       65       -1.86
# 26  1999                    1058                       73        1.30
# 27  2000                    1132                      102        1.22
# 28  2001                    1334                       91        1.24
# 29  2002                     938                      150        0.24
# 30  2003                     849                       75       -0.56
# 31  2004                     825                       96        0.22
# 32  2005                     818                       73       -0.80
#
#     ultimos_10
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28       False
# 29       False
# 30       False
# 31       False
# 32       False

# %%
sns.set(rc={"figure.dpi":100,'figure.figsize':(19.2,9.6)})
norm = plt.Normalize()

ax = sns.histplot(data=san_luis_soi,x='max_precipitacion_anual',kde=True,element="step",stat='frequency',color=norm((235,133,115)))
ax.set_title("Frecuncia de máxima precipitación anual en el periodo 1973-2005")
ax.set_xlabel("Maxima precipitación en mm")
fig = ax.get_figure()
fig.savefig("histograma_san_luis.png")

# %%
ultimos_diez = san_luis_soi.groupby(['ultimos_10']).get_group(True)
ultimos_diez
# Out:
#      año tot_precipitacion_anual  max_precipitacion_anual  indice SOI  \
# 17  1990                     683                       45       -0.60
# 18  1991                    1085                       67       -0.10
# 19  1992                     860                       67       -1.66
# 20  1993                    1027                       88       -0.68
# 21  1994                     823                       71       -0.08
# 22  1995                     624                       63       -0.30
# 23  1996                     830                      122        0.38
# 24  1997                    1041                       67        0.52
# 25  1998                     979                       65       -1.86
# 26  1999                    1058                       73        1.30
# 27  2000                    1132                      102        1.22
#
#     ultimos_10
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True

# %%
clrs = [(58,180,250) if (y > 0) else (255,104,91) for y in ultimos_diez['indice SOI'] ]
norm = plt.Normalize()

sns.set(rc={"figure.dpi":200,'figure.figsize':(19.2,9.6)})
ax = sns.barplot(data=ultimos_diez,x='año',y='indice SOI',palette=norm(clrs))
ax.set_title("Comportamiento de El Niño y La Niña durante el periodo 1990-2000")
ax.set_xlabel("Años")
ax.set_ylabel("SOI")
fig = ax.get_figure()
fig.savefig("elnino_la_nina.png")
